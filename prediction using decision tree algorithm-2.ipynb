# %% [markdown]
# ### Abhishek Siripalli
#
# Prediction using decision tree algorithm

# %% [markdown]
# ### Importing libraries in python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Read the dataset

# %%
data = "Iris.csv"
load = pd.read_csv(data)
load
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
load.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Checking the general statistical info of data

# %%
load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
load.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Checking if there are any null values

# %%
load.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
load.duplicated().sum()
# Out:
# 0

# %%
load.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# ### Visuallization through heat map

# %%
correlation=sns.heatmap(load.corr(),annot=True)

# %% [markdown]
# ### Relationship of the data

# %%
x=load[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=load[['Species']]

# %% [markdown]
# ### Splitting the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print('shape of x trainset{}'.format(x_train.shape),'shape of x testset{}'.format(x_test.shape))
# Out:
# shape of x trainset(120, 4) shape of x testset(30, 4)

# %%
print("Shape of X Train : ", x_train.shape)
print("Shape of X Test  : ", x_test.shape)
print("Shape of Y Train : ", y_train.shape)
print("Shape of Y Test  : ", y_test.shape)
# Out:
# Shape of X Train :  (120, 4)
# Shape of X Test  :  (30, 4)
# Shape of Y Train :  (120, 1)
# Shape of Y Test  :  (30, 1)

# %% [markdown]
# ### Defining the decision tree algorithm

# %%
dtree=DecisionTreeClassifier()
dtree.fit(x_train,y_train)

print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
# !pip install pydotplus
# !pip install graphviz
# Out:
# ...
#      |████████████████████████████████| 46 kB 7.6 MB/s eta 0:00:011
# ...

# %%
tree_classifier=DecisionTreeClassifier(criterion='entropy')

# %%
tree_classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=tree_classifier.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Accuracy of the data

# %%
from sklearn import metrics
print("model_accuracy",metrics.accuracy_score(y_test,y_pred))
# Out:
# model_accuracy 0.9

# %% [markdown]
# ###  Visualize the graph

# %%
from sklearn import tree
plt.figure(figsize=(25,25))
tree.plot_tree(tree_classifier,rounded=True,filled=True)
# Out:
# [Text(558.0, 1274.0625, 'X[2] <= 2.45\nentropy = 1.581\nsamples = 120\nvalue = [44, 37, 39]'),
#  Text(418.5, 1104.1875, 'entropy = 0.0\nsamples = 44\nvalue = [44, 0, 0]'),
#  Text(697.5, 1104.1875, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 76\nvalue = [0, 37, 39]'),
#  Text(279.0, 934.3125, 'X[3] <= 1.45\nentropy = 0.391\nsamples = 39\nvalue = [0, 36, 3]'),
#  Text(139.5, 764.4375, 'entropy = 0.0\nsamples = 26\nvalue = [0, 26, 0]'),
#  Text(418.5, 764.4375, 'X[1] <= 2.85\nentropy = 0.779\nsamples = 13\nvalue = [0, 10, 3]'),
#  Text(279.0, 594.5625, 'X[0] <= 5.45\nentropy = 1.0\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(139.5, 424.6875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(418.5, 424.6875, 'X[2] <= 4.8\nentropy = 0.971\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(279.0, 254.8125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(558.0, 254.8125, 'X[3] <= 1.55\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
# ...
